# %% [markdown]
# # Homework part I
#
# The first problem set contains basic tasks in pytorch.
#
# __Note:__ Instead of doing this part of homework, you can prove your skills otherwise:
# * A commit to pytorch or pytorch-based repos will do;
# * Fully implemented seminar assignment in tensorflow or theano will do;
# * Your own project in pytorch that is developed to a state in which a normal human can understand and appreciate what it does.

# %%
from __future__ import print_function
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import torch, torch.nn as nn
import torch.nn.functional as F
from torch.autograd import Variable
print(torch.__version__)
# Out:
# 0.4.0a0+da6c3c9

# %% [markdown]
# ### Task I - tensormancy
#
# ![img](https://media.giphy.com/media/3o751UMCYtSrRAFRFC/giphy.gif)
#
# When dealing with more complex stuff like neural network, it's best if you use tensors the way samurai uses his sword.
#
#
# __1.1 the cannabola__
# [_disclaimer_](https://gist.githubusercontent.com/justheuristic/e2c1fa28ca02670cabc42cacf3902796/raw/fd3d935cef63a01b85ed2790b5c11c370245cbd7/stddisclaimer.h)
#
# Let's write another function, this time in polar coordinates:
# $$\rho(\theta) = (1 + 0.9 \cdot cos (8 \cdot \theta) ) \cdot (1 + 0.1 \cdot cos(24 \cdot \theta)) \cdot (0.9 + 0.05 \cdot cos(200 \cdot \theta)) \cdot (1 + sin(\theta))$$
#
#
# Then convert it into cartesian coordinates ([howto](http://www.mathsisfun.com/polar-cartesian-coordinates.html)) and plot the results.
#
# Use torch tensors only: no lists, loops, numpy arrays, etc.

# %%
theta = torch.linspace(- np.pi, np.pi, steps=1000)

# compute rho(theta) as per formula above
rho = (1 + 0.9 * torch.cos(8 * theta)) * (1 + 0.1 * torch.cos(24 * theta)) * \
(0.9 + 0.05 * torch.cos(200 * theta)) * (1 + torch.sin(theta))

# Now convert polar (rho, theta) pairs into cartesian (x,y) to plot them.
x = rho * torch.cos(theta)
y = rho * torch.sin(theta)


plt.figure(figsize=[6,6])
plt.fill(x.numpy(), y.numpy(), color='green')
plt.grid()

# %% [markdown]
# ### Task II: the game of life
#
# Now it's time for you to make something more challenging. We'll implement Conway's [Game of Life](http://web.stanford.edu/~cdebs/GameOfLife/) in _pure pytorch_.
#
# While this is still a toy task, implementing game of life this way has one cool benefit: __you'll be able to run it on GPU! __ Indeed, what could be a better use of your gpu than simulating game of life on 1M/1M grids?
#
# ![img](https://cdn.tutsplus.com/gamedev/authors/legacy/Stephane%20Beniak/2012/09/11/Preview_Image.png)
# If you've skipped the url above out of sloth, here's the game of life:
# * You have a 2D grid of cells, where each cell is "alive"(1) or "dead"(0)
# * Any living cell that has 2 or 3 neighbors survives, else it dies [0,1 or 4+ neighbors]
# * Any cell with exactly 3 neighbors becomes alive (if it was dead)
#
# For this task, you are given a reference numpy implementation that you must convert to pytorch.
# _[numpy code inspired by: https://github.com/rougier/numpy-100]_
#
#
# __Note:__ You can find convolution in `torch.nn.functional.conv2d(Z,filters)`. Note that it has a different input format.

# %%
from scipy.signal import convolve2d

def np_update(Z):
    # Count neighbours with convolution
    filters = np.array([[1,1,1],
                        [1,0,1],
                        [1,1,1]])
    
    N = convolve2d(Z,filters,mode='same')
    
    # Apply rules
    birth = (N==3) & (Z==0)
    survive = ((N==2) | (N==3)) & (Z==1)
    
    Z[:] = birth | survive
    return Z

# %%
from torch.nn.functional import conv2d

def torch_update(Z):
    """
    Implement an update function that does to Z exactly the same as np_update.
    :param Z: torch.FloatTensor of shape [height,width] containing 0s(dead) an 1s(alive)
    :returns: torch.FloatTensor Z after updates.
    You can opt to create new tensor or change Z inplace.
    """
    filters = torch.Tensor([[1.,1.,1.],
                        [1.,0.,1.],
                        [1.,1.,1.]]).reshape(1,1,3,3)
    Z = Z.reshape(1, 1, Z.size()[0], Z.size()[1])
    N = conv2d(Z,filters, padding=1)
    N = N.reshape(N.size()[2], N.size()[3])
    Z = Z.reshape(Z.size()[2], Z.size()[3])
    birth = (N==3) & (Z==0)
    survive = ((N==2) | (N==3)) & (Z==1)
    
    Z[:] = birth | survive
    return Z

# %%
#initial frame
Z_numpy = np.random.choice([0,1],p=(0.5,0.5),size=(100,100))
Z = torch.from_numpy(Z_numpy).type(torch.FloatTensor)

#your debug polygon :)
Z_new = torch_update(Z.clone())

#tests
Z_reference = np_update(Z_numpy.copy())
assert np.all(Z_new.numpy() == Z_reference), "your pytorch implementation doesn't match np_update. Look into Z and np_update(ZZ) to investigate."
print("Well done!")
# Out:
# Well done!

# %%
# %matplotlib notebook
plt.ion()

#initialize game field
Z = np.random.choice([0,1],size=(100,100))
Z = torch.from_numpy(Z).type(torch.FloatTensor)

fig = plt.figure()
ax = fig.add_subplot(111)
fig.show()

for _ in range(100):
    
    #update
    Z = torch_update(Z)
    #re-draw image
    ax.clear()
    ax.imshow(Z.numpy(),cmap='gray')
    fig.canvas.draw()
# Out:
# <img src="data:image/png;base64,..." width="432">
# <img src="data:image/png;base64,..." width="432">

# %%
#Some fun setups for your amusement

#parallel stripes
Z = np.arange(100)%2 + np.zeros([100,100])
#with a small imperfection
Z[48:52,50]=1

Z = torch.from_numpy(Z).type(torch.FloatTensor)

fig = plt.figure()
ax = fig.add_subplot(111)
fig.show()

for _ in range(100):
    Z = torch_update(Z)
    ax.clear()
    ax.imshow(Z.numpy(),cmap='gray')
    fig.canvas.draw()
# Out:
# <img src="data:image/png;base64,..." width="432">
# <img src="data:image/png;base64,..." width="432">

# %% [markdown]
# More fun with Game of Life: [video](https://www.youtube.com/watch?v=C2vgICfQawE)

# %% [markdown]
# ```
#
# ```
#
# ```
#
# ```
#
# ```
#
# ```
#
# ```
#
# ```
#
# ```
#
# ```
#
#
#
# ### Task III: Going deeper
# <img src="http://download.gamezone.com/uploads/image/data/1190338/article_post_width_a88.jpg" width=360>
# Your third trial is to build your first neural network [almost] from scratch and pure torch.
#
# This time you will solve yet another digit recognition problem, but at a greater scale
# * 10 different letters
# * 20k samples
#
# We want you to build a network that reaches at least 80% accuracy and has at least 2 linear layers in it. Naturally, it should be nonlinear to beat logistic regression. You can implement it with either
#
#
# With 10 classes you will need to use __Softmax__ at the top instead of sigmoid and train for __categorical crossentropy__  (see [here](https://www.kaggle.com/wiki/LogLoss)).  Write your own loss or use `torch.nn.functional.nll_loss`. Just make sure you understand what it accepts as an input.
#
# Note that you are not required to build 152-layer monsters here. A 2-layer (one hidden, one output) neural network should already give you an edge over logistic regression.
#
#
# __[bonus kudos]__
# If you've already beaten logistic regression with a two-layer net, but enthusiasm still ain't gone, you can try improving the test accuracy even further! It should be possible to reach 90% without convnets.
#
# __SPOILERS!__
# At the end of the notebook you will find a few tips and frequent errors.
# If you feel confident enogh, just start coding right away and get there ~~if~~ once you need to untangle yourself.

# %%
from notmnist import load_notmnist
X_train, y_train, X_test, y_test = load_notmnist(letters='ABCDEFGHIJ')
X_train, X_test = X_train.reshape([-1, 784]), X_test.reshape([-1, 784])
# Out:
# Parsing...
# found broken img: ./notMNIST_small/A/RGVtb2NyYXRpY2FCb2xkT2xkc3R5bGUgQm9sZC50dGY=.png [it's ok if <10 images are broken]
# found broken img: ./notMNIST_small/F/Q3Jvc3NvdmVyIEJvbGRPYmxpcXVlLnR0Zg==.png [it's ok if <10 images are broken]
# Done

# %%
# %matplotlib inline
plt.figure(figsize=[12,4])
for i in range(20):
    plt.subplot(2,10,i+1)
    plt.imshow(X_train[i].reshape([28,28]))
    plt.title(str(y_train[i]))

# %%
n_features = X_train.shape[1]
model = nn.Sequential()
model.add_module('dense1', nn.Linear(n_features, 150))
model.add_module('dense1_relu', nn.ReLU())
model.add_module('dense2', nn.Linear(150, 10))
model.add_module('softmax', nn.Softmax(dim=1))

# %%
def iterate_minibatches(X, y, batchsize):
    indices = np.random.permutation(np.arange(len(X)))
    for start in range(0, len(indices), batchsize):
        ix = indices[start: start + batchsize]
        yield X[ix], y[ix]

# %%
opt = torch.optim.SGD(model.parameters(), lr=0.01)

train_loss = []
val_accuracy = []

# %%
import time
num_epochs = 100 # total amount of full passes over training data
batch_size = 100  # number of samples processed in one SGD iteration

for epoch in range(num_epochs):
    # In each epoch, we do a full pass over the training data:
    start_time = time.time()
    model.train(True) # enable dropout / batch_norm training behavior
    for X_batch, y_batch in iterate_minibatches(X_train, y_train, batch_size):
        # train on batch
        loss = torch.nn.functional.nll_loss(model(Variable(torch.FloatTensor(X_batch))), Variable(torch.LongTensor(y_batch)))
        loss.backward()
        opt.step()
        opt.zero_grad()
        train_loss.append(loss.data.numpy())
        
    # And a full pass over the validation data:
    model.train(False) # disable dropout / use averages for batch_norm
    for X_batch, y_batch in iterate_minibatches(X_test, y_test, batch_size):
        logits = model(Variable(torch.FloatTensor(X_batch)))
        y_pred = logits.max(1)[1].data.numpy()
        val_accuracy.append(np.mean(y_batch == y_pred))

    
    # Then we print the results for this epoch:
    print("Epoch {} of {} took {:.3f}s".format(
        epoch + 1, num_epochs, time.time() - start_time))
    print("  training loss (in-iteration): \t{:.6f}".format(
        np.mean(train_loss[-len(X_train) // batch_size :])))
    print("  test accuracy: \t\t\t{:.2f} %".format(
        np.mean(val_accuracy[-len(X_test) // batch_size :]) * 100))
# Out:
# Epoch 1 of 100 took 4.448s
#   training loss (in-iteration): 	-0.115691
#   test accuracy: 			38.73 %
# Epoch 2 of 100 took 4.128s
#   training loss (in-iteration): 	-0.181606
#   test accuracy: 			51.56 %
# Epoch 3 of 100 took 3.578s
#   training loss (in-iteration): 	-0.321866
#   test accuracy: 			62.49 %
# Epoch 4 of 100 took 4.074s
#   training loss (in-iteration): 	-0.492283
#   test accuracy: 			76.83 %
# Epoch 5 of 100 took 3.661s
#   training loss (in-iteration): 	-0.628861
#   test accuracy: 			82.75 %
# Epoch 6 of 100 took 3.372s
#   training loss (in-iteration): 	-0.711616
#   test accuracy: 			84.47 %
# Epoch 7 of 100 took 3.743s
#   training loss (in-iteration): 	-0.754422
#   test accuracy: 			85.26 %
# Epoch 8 of 100 took 3.614s
#   training loss (in-iteration): 	-0.779954
#   test accuracy: 			85.65 %
# Epoch 9 of 100 took 3.747s
#   training loss (in-iteration): 	-0.796317
#   test accuracy: 			85.98 %
# Epoch 10 of 100 took 3.783s
#   training loss (in-iteration): 	-0.808269
#   test accuracy: 			86.43 %
# Epoch 11 of 100 took 3.997s
#   training loss (in-iteration): 	-0.816812
#   test accuracy: 			86.78 %
# Epoch 12 of 100 took 4.150s
#   training loss (in-iteration): 	-0.824088
#   test accuracy: 			86.85 %
# Epoch 13 of 100 took 3.883s
#   training loss (in-iteration): 	-0.829558
#   test accuracy: 			87.05 %
# Epoch 14 of 100 took 5.126s
#   training loss (in-iteration): 	-0.834195
#   test accuracy: 			87.11 %
# Epoch 15 of 100 took 3.849s
#   training loss (in-iteration): 	-0.838440
#   test accuracy: 			87.11 %
# Epoch 16 of 100 took 3.575s
#   training loss (in-iteration): 	-0.842281
#   test accuracy: 			87.23 %
# Epoch 17 of 100 took 3.609s
#   training loss (in-iteration): 	-0.844990
#   test accuracy: 			87.21 %
# Epoch 18 of 100 took 3.619s
#   training loss (in-iteration): 	-0.847961
#   test accuracy: 			87.41 %
# Epoch 19 of 100 took 3.715s
#   training loss (in-iteration): 	-0.850389
#   test accuracy: 			87.54 %
# Epoch 20 of 100 took 4.141s
#   training loss (in-iteration): 	-0.852628
#   test accuracy: 			87.61 %
# Epoch 21 of 100 took 5.556s
#   training loss (in-iteration): 	-0.854637
#   test accuracy: 			87.74 %
# Epoch 22 of 100 took 4.120s
#   training loss (in-iteration): 	-0.856625
#   test accuracy: 			87.82 %
# Epoch 23 of 100 took 4.942s
#   training loss (in-iteration): 	-0.858196
#   test accuracy: 			87.81 %
# Epoch 24 of 100 took 3.747s
#   training loss (in-iteration): 	-0.860075
#   test accuracy: 			87.93 %
# Epoch 25 of 100 took 3.696s
#   training loss (in-iteration): 	-0.862052
#   test accuracy: 			88.04 %
# Epoch 26 of 100 took 3.463s
#   training loss (in-iteration): 	-0.863593
#   test accuracy: 			88.09 %
# Epoch 27 of 100 took 3.764s
#   training loss (in-iteration): 	-0.864553
#   test accuracy: 			88.11 %
# Epoch 28 of 100 took 3.503s
#   training loss (in-iteration): 	-0.866296
#   test accuracy: 			88.15 %
# Epoch 29 of 100 took 4.244s
#   training loss (in-iteration): 	-0.867467
#   test accuracy: 			88.24 %
# Epoch 30 of 100 took 3.892s
#   training loss (in-iteration): 	-0.868569
#   test accuracy: 			88.36 %
# Epoch 31 of 100 took 3.778s
#   training loss (in-iteration): 	-0.869950
#   test accuracy: 			88.45 %
# Epoch 32 of 100 took 3.969s
#   training loss (in-iteration): 	-0.870928
#   test accuracy: 			88.49 %
# Epoch 33 of 100 took 4.032s
#   training loss (in-iteration): 	-0.871649
#   test accuracy: 			88.58 %
# Epoch 34 of 100 took 3.618s
#   training loss (in-iteration): 	-0.873033
#   test accuracy: 			88.67 %
# Epoch 35 of 100 took 5.042s
#   training loss (in-iteration): 	-0.873766
#   test accuracy: 			88.68 %
# Epoch 36 of 100 took 4.840s
#   training loss (in-iteration): 	-0.874635
#   test accuracy: 			88.62 %
# Epoch 37 of 100 took 4.171s
#   training loss (in-iteration): 	-0.875410
#   test accuracy: 			88.63 %
# Epoch 38 of 100 took 4.411s
#   training loss (in-iteration): 	-0.876217
#   test accuracy: 			88.64 %
# Epoch 39 of 100 took 5.875s
#   training loss (in-iteration): 	-0.877016
#   test accuracy: 			88.81 %
# Epoch 40 of 100 took 4.670s
#   training loss (in-iteration): 	-0.878249
#   test accuracy: 			88.76 %
# Epoch 41 of 100 took 3.398s
#   training loss (in-iteration): 	-0.878715
#   test accuracy: 			88.79 %
# Epoch 42 of 100 took 3.626s
#   training loss (in-iteration): 	-0.879184
#   test accuracy: 			88.81 %
# Epoch 43 of 100 took 4.504s
#   training loss (in-iteration): 	-0.880146
#   test accuracy: 			88.93 %
# Epoch 44 of 100 took 6.591s
#   training loss (in-iteration): 	-0.880764
#   test accuracy: 			88.91 %
# Epoch 45 of 100 took 5.090s
#   training loss (in-iteration): 	-0.881106
#   test accuracy: 			88.93 %
# Epoch 46 of 100 took 5.859s
#   training loss (in-iteration): 	-0.881926
#   test accuracy: 			89.03 %
# Epoch 47 of 100 took 4.318s
#   training loss (in-iteration): 	-0.883013
#   test accuracy: 			89.02 %
# Epoch 48 of 100 took 4.290s
#   training loss (in-iteration): 	-0.883375
#   test accuracy: 			89.15 %
# Epoch 49 of 100 took 4.257s
#   training loss (in-iteration): 	-0.884021
#   test accuracy: 			89.22 %
# Epoch 50 of 100 took 4.393s
#   training loss (in-iteration): 	-0.884410
#   test accuracy: 			89.21 %
# Epoch 51 of 100 took 4.345s
#   training loss (in-iteration): 	-0.885490
#   test accuracy: 			89.26 %
# Epoch 52 of 100 took 4.761s
#   training loss (in-iteration): 	-0.885587
#   test accuracy: 			89.31 %
# Epoch 53 of 100 took 5.511s
#   training loss (in-iteration): 	-0.886375
#   test accuracy: 			89.28 %
# Epoch 54 of 100 took 5.360s
#   training loss (in-iteration): 	-0.887011
#   test accuracy: 			89.33 %
# Epoch 55 of 100 took 5.481s
#   training loss (in-iteration): 	-0.887549
#   test accuracy: 			89.34 %
# Epoch 56 of 100 took 4.399s
#   training loss (in-iteration): 	-0.888336
#   test accuracy: 			89.34 %
# Epoch 57 of 100 took 3.823s
#   training loss (in-iteration): 	-0.888811
#   test accuracy: 			89.40 %
# Epoch 58 of 100 took 5.064s
#   training loss (in-iteration): 	-0.889174
#   test accuracy: 			89.45 %
# Epoch 59 of 100 took 3.703s
#   training loss (in-iteration): 	-0.889756
#   test accuracy: 			89.48 %
# Epoch 60 of 100 took 3.849s
#   training loss (in-iteration): 	-0.890397
#   test accuracy: 			89.47 %
# Epoch 61 of 100 took 4.561s
#   training loss (in-iteration): 	-0.890739
#   test accuracy: 			89.52 %
# Epoch 62 of 100 took 4.489s
#   training loss (in-iteration): 	-0.891338
#   test accuracy: 			89.53 %
# Epoch 63 of 100 took 3.860s
#   training loss (in-iteration): 	-0.891848
#   test accuracy: 			89.53 %
# Epoch 64 of 100 took 3.930s
#   training loss (in-iteration): 	-0.892298
#   test accuracy: 			89.60 %
# Epoch 65 of 100 took 3.699s
#   training loss (in-iteration): 	-0.892516
#   test accuracy: 			89.59 %
# Epoch 66 of 100 took 3.567s
#   training loss (in-iteration): 	-0.892921
#   test accuracy: 			89.63 %
# Epoch 67 of 100 took 4.293s
#   training loss (in-iteration): 	-0.893476
#   test accuracy: 			89.67 %
# Epoch 68 of 100 took 3.639s
#   training loss (in-iteration): 	-0.893908
#   test accuracy: 			89.68 %
# Epoch 69 of 100 took 3.551s
#   training loss (in-iteration): 	-0.894378
#   test accuracy: 			89.73 %
# Epoch 70 of 100 took 4.398s
#   training loss (in-iteration): 	-0.894929
#   test accuracy: 			89.78 %
# Epoch 71 of 100 took 4.717s
#   training loss (in-iteration): 	-0.895069
#   test accuracy: 			89.80 %
# Epoch 72 of 100 took 3.958s
#   training loss (in-iteration): 	-0.895493
#   test accuracy: 			89.80 %
# Epoch 73 of 100 took 5.323s
#   training loss (in-iteration): 	-0.896225
#   test accuracy: 			89.89 %
# Epoch 74 of 100 took 5.931s
#   training loss (in-iteration): 	-0.896423
#   test accuracy: 			89.85 %
# Epoch 75 of 100 took 4.192s
#   training loss (in-iteration): 	-0.896680
#   test accuracy: 			89.88 %
# Epoch 76 of 100 took 3.568s
#   training loss (in-iteration): 	-0.897380
#   test accuracy: 			89.87 %
# Epoch 77 of 100 took 3.758s
#   training loss (in-iteration): 	-0.897362
#   test accuracy: 			89.90 %
# Epoch 78 of 100 took 3.562s
#   training loss (in-iteration): 	-0.898144
#   test accuracy: 			89.93 %
# Epoch 79 of 100 took 3.547s
#   training loss (in-iteration): 	-0.898400
#   test accuracy: 			89.98 %
# Epoch 80 of 100 took 3.641s
#   training loss (in-iteration): 	-0.898406
#   test accuracy: 			89.95 %
# Epoch 81 of 100 took 3.138s
#   training loss (in-iteration): 	-0.899062
#   test accuracy: 			89.91 %
# Epoch 82 of 100 took 3.171s
#   training loss (in-iteration): 	-0.899193
#   test accuracy: 			89.92 %
# Epoch 83 of 100 took 5.008s
#   training loss (in-iteration): 	-0.899723
#   test accuracy: 			89.94 %
# Epoch 84 of 100 took 5.403s
#   training loss (in-iteration): 	-0.900144
#   test accuracy: 			90.03 %
# Epoch 85 of 100 took 4.150s
#   training loss (in-iteration): 	-0.900537
#   test accuracy: 			90.01 %
# Epoch 86 of 100 took 4.355s
#   training loss (in-iteration): 	-0.900731
#   test accuracy: 			90.00 %
# Epoch 87 of 100 took 4.144s
#   training loss (in-iteration): 	-0.901081
#   test accuracy: 			90.09 %
# Epoch 88 of 100 took 4.167s
#   training loss (in-iteration): 	-0.901587
#   test accuracy: 			90.08 %
# Epoch 89 of 100 took 4.199s
#   training loss (in-iteration): 	-0.901882
#   test accuracy: 			90.17 %
# Epoch 90 of 100 took 5.376s
#   training loss (in-iteration): 	-0.902060
#   test accuracy: 			90.11 %
# Epoch 91 of 100 took 5.533s
#   training loss (in-iteration): 	-0.902400
#   test accuracy: 			90.11 %
# Epoch 92 of 100 took 4.995s
#   training loss (in-iteration): 	-0.902166
#   test accuracy: 			90.16 %
# Epoch 93 of 100 took 4.308s
#   training loss (in-iteration): 	-0.902969
#   test accuracy: 			90.20 %
# Epoch 94 of 100 took 4.886s
#   training loss (in-iteration): 	-0.903448
#   test accuracy: 			90.17 %
# Epoch 95 of 100 took 4.348s
#   training loss (in-iteration): 	-0.903621
#   test accuracy: 			90.19 %
# Epoch 96 of 100 took 4.207s
#   training loss (in-iteration): 	-0.903635
#   test accuracy: 			90.23 %
# Epoch 97 of 100 took 4.563s
#   training loss (in-iteration): 	-0.904106
#   test accuracy: 			90.20 %
# Epoch 98 of 100 took 4.886s
#   training loss (in-iteration): 	-0.904408
#   test accuracy: 			90.24 %
# Epoch 99 of 100 took 4.786s
#   training loss (in-iteration): 	-0.904699
#   test accuracy: 			90.28 %
# Epoch 100 of 100 took 4.231s
#   training loss (in-iteration): 	-0.905030
#   test accuracy: 			90.32 %

# %% [markdown]
# ```
#
# ```
#
# ```
#
# ```
#
# ```
#
# ```
#
# ```
#
# ```
#
# ```
#
# ```
#
# ```
#
# ```
#
# ```
#
# ```
#
# ```
#
# ```
#
# ```
#
# ```
#
# ```
#
# ```
#
# ```
#
# ```
#
# ```
#
# ```
#
# ```
#
# ```
#
# ```
#
# ```
#
# ```
#
# ```
#
#
# # SPOILERS!
#
# Recommended pipeline
#
# * Adapt logistic regression from week2 seminar assignment to classify one letter against others (e.g. A vs the rest)
# * Generalize it to multiclass logistic regression.
#   - Either try to remember lecture 0 or google it.
#   - Instead of weight vector you'll have to use matrix (feature_id x class_id)
#   - softmax (exp over sum of exps) can implemented manually or as nn.Softmax (layer) F.softmax (function)
#   - probably better to use STOCHASTIC gradient descent (minibatch) for greater speed
#     - you can also try momentum/rmsprop/adawhatever
#     - in which case sample should probably be shuffled (or use random subsamples on each iteration)
# * Add a hidden layer. Now your logistic regression uses hidden neurons instead of inputs.
#   - Hidden layer uses the same math as output layer (ex-logistic regression), but uses some nonlinearity (e.g. sigmoid) instead of softmax
#   - You need to train both layers, not just output layer :)
#   - __Do not initialize weights with zeros__ (due to symmetry effects). A gaussian noize with small variance will do.
#   - 50 hidden neurons and a sigmoid nonlinearity will do for a start. Many ways to improve.
#   - In ideal casae this totals to 2 .dot's, 1 softmax and 1 sigmoid
#   - __make sure this neural network works better than logistic regression__
#
# * Now's the time to try improving the network. Consider layers (size, neuron count),  nonlinearities, optimization methods, initialization - whatever you want, but please avoid convolutions for now.
#
# * If anything seems wrong, try going through one step of training and printing everything you compute.
# * If you see NaNs midway through optimization, you can estimate log P(y|x) as via F.log_softmax(layer_before_softmax)
